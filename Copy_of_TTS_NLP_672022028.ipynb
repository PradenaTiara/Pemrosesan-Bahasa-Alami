# %% [markdown]
# <a href="https://colab.research.google.com/github/PradenaTiara/Pemrosesan-Bahasa-Alami/blob/main/Copy_of_TTS_NLP_672022028.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Petunjuk TTS**
#
# Silakan simpan file ke dalam bentuk **TTS_NLP_NIM.ipynb**. Soal terbagi teori dan praktek; untuk teori langsung tuliskan jawaban dalam bentuk TEXT, sedangkan untuk praktek, tuliskan koding untuk dapat menampilkan hasil seperti yang diminta.
#
# Setelah selesai mengerjakan, silakan unggah ke GClass. Waktu kalian 90 menit. Jangan sampai terlambat ya...tidak ada toleransi untuk keterlambatan.
#
# Have fun!

# %% [markdown]
# **SOAL TEORI**
#
# 1. Berikan penjelasan singkat, apa itu Pemrosesan Bahasa Alami atau NLP? (Tidak lebih dari 50 kata).
# 2. Ada kurang lebih 5 tantangan dari Pemrosesan Bahasa Alami. Sebutkan dan jelaskan, tidak lebih dari 200 kata.
# 3. Jelaskan secara singkat arti dari gambar berikut:![fase-text-processing.png](data:image/png;base64,...)

# %% [markdown]
# **Jawaban Soal Teori**
#
# 1. Pemrosesan Bahasa Alami(NLP) adalah cabang kecerdasan buatan yang memungkinkan komputer memahami, menginterpretasi, dan menghasilkan bahasa manusia secara alami untuk keperluan komunikasi, analisis data, dan interaksi manusia-mesin secara otomatis dan cerdas.
#
# 2. a. Produktivitas
# Sifat dari sistem bahasa yang memungkinkan penutur asli untuk membentuk dan memahami jumlah ujaran yang tak terbatas, termasuk yang belum pernah mereka temui sebelumnya. (Lyons, 1977)
# Contoh: kata "staycation" dan "social distance" ditambahkan ke Oxford Dictionary pada 2021.
# b. Ambiguitas
# Sebagian besar ucapan atau teks bisa memiliki beberapa interpretasi.
# Manusia bisa membedakan makna menggunakan berbagai sinyal linguistik dan non-linguistik.
# Ambiguitas bisa terjadi di semua tingkatan (fonologi, morfologi, sintaksis, semantik).
# contoh : Polysemy:  kata “set”, “arm”, “head”
# → "Kepala negara Selandia Baru adalah seorang wanita" (ambigu karena kepala adalah anggota tubuh dan negara adalah country, yang di mana kepala negara itu harusnya di gabung tidak bisa di pisah)
# c. Variasi
# Bahasa bervariasi di semua tingkatan:
# - Fonetik yaitu aksen
# - Morfologis, Leksikal yang sering dikenal dengan ejaan
# - Sintaksis
# - Semantik
# Penentu Variasi:
# - Siapa yang berbicara?
# - Kepada siapa?
# - Di mana? (rumah, kantor, restoran)
# - Kapan? (abad ke-19, 2008, 2022)
# - Tentang apa? (cuaca, topik spesifik)
# d. Keanekaragaman
# e. Kelangkaan
#
# 3. Document (Full Text): Dokumen mentah yang berisi teks lengkap.
# Parsing: Struktur teks dianalisis untuk memisahkan elemen penting (misalnya, kalimat, paragraf).
# Lexical Analysis: Teks dipecah menjadi token (kata atau frasa).
# Stop-word Removal: Kata umum seperti “dan”, “yang”, “adalah” dihapus karena tidak membawa makna penting.
# Phrase Detection: Deteksi frasa penting (seperti "machine learning") yang harus dipertahankan sebagai satu kesatuan.
# Stemming & Lemmatization: Kata dikembalikan ke bentuk dasarnya (contoh: "running" → "run").
# Weighting: Setiap kata atau frasa diberi bobot berdasarkan pentingnya dalam dokumen (misalnya TF-IDF).
# Indexing: Hasil akhir disimpan dalam bentuk indeks untuk mempermudah pencarian.
# Garis putus-putus Menunjukkan bahwa istilah untuk indexing bisa berasal dari berbagai tahap: dari teks penuh, hasil phrase detection, hasil stemming, serta lainnya, tergantung sistem yang digunakan.
# Singkatnya, diagram ini menggambarkan bagaimana teks dari dokumen diolah secara bertahap untuk menghasilkan kata-kata kunci yang relevan untuk pencarian informasi. Proses yang bertujuan untuk mengubah dokumen teks menjadi representasi yang efisien dan informatif untuk mendukung pencarian informasi yang cepat dan akurat. Tahap-tahap ini merupakan bagian penting dalam sistem seperti search engine, rekomendasi dokumen, dan analisis teks serta NLP.

# %% [markdown]
# **SOAL PRAKTEK**

# %% [markdown]
# 1. BBC News

# %%
# install pandas profiling
! pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
! pip3 install datasets
# Out:
# ...
#      \ 17.9 MB 24.1 MB/s 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 87.5 MB/s eta 0:00:00
# ...
#   Created wheel for ydata-profiling: filename=ydata_profiling-0.0.dev0-py2.py3-none-any.whl size=400139 sha256=2dce3b655c67fb285562b6b6e8e9567b1f678fe131501b86efe13fb2dfa6a281
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j8s7jcck/wheels/85/5d/45/8a23c7b77d2023fbc37490b8902f7fdeff5614f65d6e08b6c4
# ...

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

from functools import reduce
from operator import add
from termcolor import colored
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# <ipython-input-5-9d89c47a7176>:3: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
# Ambil data dari https://gitlab.com/gguibon/ensae-ml4nlp-storage/-/raw/master/bbc-news-data.zip
! wget https://gitlab.com/gguibon/ensae-ml4nlp-storage/-/raw/master/bbc-news-data.zip
! unzip bbc-news-data.zip
# Out:
# --2025-05-26 03:22:19--  https://gitlab.com/gguibon/ensae-ml4nlp-storage/-/raw/master/bbc-news-data.zip
# Resolving gitlab.com (gitlab.com)... 172.65.251.78, 2606:4700:90:0:f22e:fbec:5bed:a9b9
# Connecting to gitlab.com (gitlab.com)|172.65.251.78|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1896286 (1.8M) [application/octet-stream]
# Saving to: ‘bbc-news-data.zip’
#
# bbc-news-data.zip   100%[===================>]   1.81M  --.-KB/s    in 0.05s
#
# 2025-05-26 03:22:19 (36.8 MB/s) - ‘bbc-news-data.zip’ saved [1896286/1896286]
#
# Archive:  bbc-news-data.zip
#   inflating: bbc-news-data.csv

# %%
# load data tersebut ke DataFrame kita
df = pd.read_csv('./bbc-news-data.csv', sep='\t')
print("Shape:  {0}".format(df.shape))
df.head()
# Out:
# Shape:  (2225, 4)
#    category filename                              title  \
# 0  business  001.txt  Ad sales boost Time Warner profit
# 1  business  002.txt   Dollar gains on Greenspan speech
# 2  business  003.txt  Yukos unit buyer faces loan claim
# 3  business  004.txt  High fuel prices hit BA's profits
# 4  business  005.txt  Pernod takeover talk lifts Domecq
#
#                                              content
# 0   Quarterly profits at US media giant TimeWarne...
# 1   The dollar has hit its highest level against ...
# 2   The owners of embattled Russian oil giant Yuk...
# 3   British Airways has blamed high fuel prices f...
# 4   Shares in UK drinks and food firm Allied Dome...

# %%
# tampilkan jenis berita yang ada dalam kolom Kategori
print(df['category'].unique())
print(len(df['category'].unique()))
# Out:
# ['business' 'entertainment' 'politics' 'sport' 'tech']
# 5

# %%
# Buat dashboard otomatis dari dataset kita dengan menggunakan Profile Report (pandas profiling)

profil = ProfileReport(df, title="BBC News", explorative=True)
profil.to_notebook_iframe()  # untuk ditampilkan di Jupyter
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;YData Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2025-05-26 04:00:59.719374&quot;&gt;&lt;title&gt;BBC News&lt;/title&gt;&lt;style&gt;
# @charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %% [markdown]
# 2. Ambil data dari Twitter dengan keyword: "**Manchester United**", maksimal 250 data. Setelah itu tampilkan dalam dataframe. Ambil hanya kolom **full_text** untuk dianalisa. Lakukan ***cleaning*** (tidak boleh ada simbol), ***case_folding*** (huruf diubah menjadi kecil semua), ***tokenisasi*** (dipecah menjadi token), ***filtering*** dan ***stemming*** (diubah menjadi kata dasar), untuk kolom **full_text**.

# %%
#install yg dibutuhkan
# !pip install unidecode
# !pip install demoji
# !pip install contractions
# !pip install num2words
# !pip install Sastrawi nltk

# %%
import pandas as pd

df = pd.read_csv('MU.csv')  # ganti dengan nama file kamu jika beda
print(df.columns)  # untuk memastikan nama kolom yang tersedia

# Ambil hanya kolom 'full_text'
df = df[['full_text']].dropna()

df.head()
# Out:
# Index(['conversation_id_str', 'created_at', 'favorite_count', 'full_text',
#        'id_str', 'image_url', 'in_reply_to_screen_name', 'lang', 'location',
#        'quote_count', 'reply_count', 'retweet_count', 'tweet_url',
#        'user_id_str', 'username'],
#       dtype='object')
#                                                                                                                                                                                                                                                                                                  full_text
# 0                                                                                          Bruno Fernandes ke Real Madrid? Pelatih MU: Kami Ingin Juara EPL! Pelatih Manchester United (MU) Ruben Amorim dengan tegas membantah rumor kepindahan Bruno Fernandes ke Real Madrid... https://t.co/VM8m5MDpEf
# ...

# %%
# Import libraries
import pandas as pd
import re
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import re
import nltk # Import nltk for downloading the resource
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Download the 'punkt_tab' resource
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Case folding
df['case_folding'] = df['full_text'].astype(str).str.lower()
df[['full_text', 'case_folding']].head()
# Out:
#                                                                                                                                                                                                                                                                                                  full_text  \
# 0                                                                                          Bruno Fernandes ke Real Madrid? Pelatih MU: Kami Ingin Juara EPL! Pelatih Manchester United (MU) Ruben Amorim dengan tegas membantah rumor kepindahan Bruno Fernandes ke Real Madrid... https://t.co/VM8m5MDpEf
# 1  Chelsea Incar Kobbie Mainoo: Masa Depan Gelandang Muda Manchester United di Ujung Tanduk? Chelsea dikabarkan tertarik untuk merekrut gelandang muda Manchester United Kobbie Mainoo yang hingga kini belum menandatangani kontrak baru dengan klubnya. Pelatih Man United Rúben https://t.co/QJwAKIgSJG
# ...

# %%
def clean_text(text):
    return re.sub(r"http\S+|www\S+|@[\w]+|[^a-zA-Z\s]", "", text)

df['cleaned'] = df['case_folding'].apply(clean_text)
df[['case_folding', 'cleaned']].head()
# Out:
#                                                                                                                                                                                                                                                                                               case_folding  \
# 0                                                                                          bruno fernandes ke real madrid? pelatih mu: kami ingin juara epl! pelatih manchester united (mu) ruben amorim dengan tegas membantah rumor kepindahan bruno fernandes ke real madrid... https://t.co/vm8m5mdpef
# 1  chelsea incar kobbie mainoo: masa depan gelandang muda manchester united di ujung tanduk? chelsea dikabarkan tertarik untuk merekrut gelandang muda manchester united kobbie mainoo yang hingga kini belum menandatangani kontrak baru dengan klubnya. pelatih man united rúben https://t.co/qjwakigsjg
# ...

# %%
df['tokens'] = df['cleaned'].apply(word_tokenize)
df[['cleaned', 'tokens']].head()
# Out:
#                                                                                                                                                                                                                                                                         cleaned  \
# 0                                                                                              bruno fernandes ke real madrid pelatih mu kami ingin juara epl pelatih manchester united mu ruben amorim dengan tegas membantah rumor kepindahan bruno fernandes ke real madrid
# 1  chelsea incar kobbie mainoo masa depan gelandang muda manchester united di ujung tanduk chelsea dikabarkan tertarik untuk merekrut gelandang muda manchester united kobbie mainoo yang hingga kini belum menandatangani kontrak baru dengan klubnya pelatih man united rben
# ...

# %%
stop_factory = StopWordRemoverFactory()
stopwords = set(stop_factory.get_stop_words())

df['filtered'] = df['tokens'].apply(lambda tokens: [t for t in tokens if t not in stopwords])
df[['tokens', 'filtered']].head()
# Out:
#                                                                                                                                                                                                                                                                                                               tokens  \
# 0                                                                                                        [bruno, fernandes, ke, real, madrid, pelatih, mu, kami, ingin, juara, epl, pelatih, manchester, united, mu, ruben, amorim, dengan, tegas, membantah, rumor, kepindahan, bruno, fernandes, ke, real, madrid]
# 1  [chelsea, incar, kobbie, mainoo, masa, depan, gelandang, muda, manchester, united, di, ujung, tanduk, chelsea, dikabarkan, tertarik, untuk, merekrut, gelandang, muda, manchester, united, kobbie, mainoo, yang, hingga, kini, belum, menandatangani, kontrak, baru, dengan, klubnya, pelatih, man, united, rben]
# ...

# %%
stem_factory = StemmerFactory()
stemmer = stem_factory.create_stemmer()

df['stemmed'] = df['filtered'].apply(lambda tokens: [stemmer.stem(t) for t in tokens])
df[['filtered', 'stemmed']].head()
# Out:
#                                                                                                                                                                                                                                                                             filtered  \
# 0                                                                                                     [bruno, fernandes, real, madrid, pelatih, mu, juara, epl, pelatih, manchester, united, mu, ruben, amorim, tegas, membantah, rumor, kepindahan, bruno, fernandes, real, madrid]
# 1  [chelsea, incar, kobbie, mainoo, masa, depan, gelandang, muda, manchester, united, ujung, tanduk, chelsea, dikabarkan, tertarik, merekrut, gelandang, muda, manchester, united, kobbie, mainoo, hingga, kini, menandatangani, kontrak, baru, klubnya, pelatih, man, united, rben]
# ...

# %%
#@title Twitter Auth Token

twitter_auth_token = 'd11e3fb658a75d3ccc8ea740ef39034de60a0c23' # change this auth token

# %%
# Import required Python package
# !pip install pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [77.5 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,729 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [47.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,387 kB]
# ...

# %%
# Crawl Data

filename = 'Manchester_United.csv'
search_keyword = 'Manchester United since:2023-04-01 until:2025-05-26 lang:id'
limit = 250

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# Found existing file ./tweets-data/Manchester_United.csv, renaming to ./tweets-data/Manchester_United.old.csv
#
# -- Scrolling... (1) (2) (3)
# Filling in keywords: Manchester United since:2023-04-01 until:2025-05-26 lang:id
#
#  (4) (5) (6)
#
# Your tweets saved to: /content/tweets-data/Manchester_United.csv
# Total tweets saved: 20
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/Manchester_United.csv
# Total tweets saved: 38
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Manchester_United.csv
# Total tweets saved: 57
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df)
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1926790095341859050  Sun May 25 23:58:51 +0000 2025               0
# 1    1926790021211685205  Sun May 25 23:58:33 +0000 2025               0
# 2    1926788942432461198  Sun May 25 23:54:16 +0000 2025               0
# 3    1926789979058971048  Sun May 25 23:58:23 +0000 2025               0
# 4    1926788810999738809  Sun May 25 23:53:45 +0000 2025               1
# 5    1926785163096113474  Sun May 25 23:39:15 +0000 2025               2
# 6    1926685267009720527  Sun May 25 23:33:39 +0000 2025               0
# 7    1926782182376276331  Sun May 25 23:27:24 +0000 2025               1
# 8    1926685253596291126  Sun May 25 23:24:56 +0000 2025               0
# 9    1926781155228918176  Sun May 25 23:23:19 +0000 2025               1
# 10   1926685253596291126  Sun May 25 23:20:18 +0000 2025               0
# 11   1926780012083998963  Sun May 25 23:18:47 +0000 2025               0
# ...

# %%
display(df['full_text'])
# Out:
# 0                                                                                 Awal datang hanya untuk numpang latihan. Tapi takdir telah ditulis lebih indah dari itu. Dia kembali untuk melengkapi lemari trofinya di Manchester United. Kepingin terakhir peninggalan SAF telah sirna. Thanks Jonny Evans https://t.co/OY0rDRM12a
# 1                                                                                                                                                                 Ruben Amorim minta maaf ke fans Manchester United atas musim yang buruk janji bangkit musim depan dan jelaskan absennya Onana &amp; Garnacho. https://t.co/jQbGAQkfX4
# 2                                                                                                                                                                                               Ternyata Manchester United semenjak Premier League baru dua kali gak ikut kompetisi Eropa apapun yaitu di tahun 2014/2015 dan 2025/2026
# ...

# %%
df.text = df.text.str.lower()
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-78-22dfd7250a3e> in <cell line: 0>()
# ----> 1 df.text = df.text.str.lower()
#       2 df.head(3)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'text'

# %% [markdown]
# 3. Buatlah perhitungan **Term Weighting ~ TF-IDF** untuk kumpulan dokumen sebagai berikut:
#
# *   d1 = "aku cinta kamu"
# *   d2 = "aku cinta kamu dan dia"
#
# *   d3 = "aku cinta kamu tapi kamu cinta dia"
# *   d4 = "aku memang cinta kamu tapi aku milih dia"

# %%
df.text = df.text.str.replace(r'https?://\S+|www\.\S+', '', regex=True)
df.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-e88a4b71ce9e> in <cell line: 0>()
# ----> 1 df.text = df.text.str.replace(r'https?://\S+|www\.\S+', '', regex=True)
#       2 df.head(3)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'text'

# %%
#ini kumpulan dokumen kita...
d1 = "aku cinta kamu"
d2 = "aku cinta kamu dan dia"
d3 = "aku cinta kamu tapi kamu cinta dia"
d4 = "aku memang cinta kamu tapi aku milih dia"

#ini gabung semua
d_string = f"{d1}{d2}{d3}{d4}"
d_semua = d1.split()+d2.split()+d3.split()+d4.split()
d_list = [d1,d2,d3,d4]

print(d_string)
print(d_semua)
print(d_list)
# Out:
# aku cinta kamuaku cinta kamu dan diaaku cinta kamu tapi kamu cinta diaaku memang cinta kamu tapi aku milih dia
# ['aku', 'cinta', 'kamu', 'aku', 'cinta', 'kamu', 'dan', 'dia', 'aku', 'cinta', 'kamu', 'tapi', 'kamu', 'cinta', 'dia', 'aku', 'memang', 'cinta', 'kamu', 'tapi', 'aku', 'milih', 'dia']
# ['aku cinta kamu', 'aku cinta kamu dan dia', 'aku cinta kamu tapi kamu cinta dia', 'aku memang cinta kamu tapi aku milih dia']

# %%
kamus_kata = {}
for data in d_semua:
  kamus_kata[data] = d_string.count(data)

print(kamus_kata)
# Out:
# {'aku': 5, 'cinta': 5, 'kamu': 5, 'dan': 1, 'dia': 3, 'tapi': 2, 'memang': 1, 'milih': 1}

# %%
#TF = frekuensi munculnya semua kata dalam dokumen
data_dict ={}
data_list =[]
for kalimat in d_list:
  for kata in d_semua:
    data_dict[kata] = kalimat.count(kata)/len(kalimat.split())
  data_list.append(data_dict)
  data_dict = {}

  print(data_list)
# Out:
# [{'aku': 0.3333333333333333, 'cinta': 0.3333333333333333, 'kamu': 0.3333333333333333, 'dan': 0.0, 'dia': 0.0, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}]
# [{'aku': 0.3333333333333333, 'cinta': 0.3333333333333333, 'kamu': 0.3333333333333333, 'dan': 0.0, 'dia': 0.0, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}, {'aku': 0.2, 'cinta': 0.2, 'kamu': 0.2, 'dan': 0.2, 'dia': 0.2, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}]
# [{'aku': 0.3333333333333333, 'cinta': 0.3333333333333333, 'kamu': 0.3333333333333333, 'dan': 0.0, 'dia': 0.0, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}, {'aku': 0.2, 'cinta': 0.2, 'kamu': 0.2, 'dan': 0.2, 'dia': 0.2, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}, {'aku': 0.14285714285714285, 'cinta': 0.2857142857142857, 'kamu': 0.2857142857142857, 'dan': 0.0, 'dia': 0.14285714285714285, 'tapi': 0.14285714285714285, 'memang': 0.0, 'milih': 0.0}]
# ...

# %%
print("Term Frequency")
for i in range(len(data_list)):
  print(f"Data{i+1} : {data_list[i]}")

  cek_ulang = []
  for d in d_list:
    periksa = set(d.split())
    cek_ulang += list(periksa)
  for cek in cek_ulang:
    kamus_kata[cek] = cek_ulang.count(cek)
# Out:
# Term Frequency
# Data1 : {'aku': 0.3333333333333333, 'cinta': 0.3333333333333333, 'kamu': 0.3333333333333333, 'dan': 0.0, 'dia': 0.0, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}
# Data2 : {'aku': 0.2, 'cinta': 0.2, 'kamu': 0.2, 'dan': 0.2, 'dia': 0.2, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}
# Data3 : {'aku': 0.14285714285714285, 'cinta': 0.2857142857142857, 'kamu': 0.2857142857142857, 'dan': 0.0, 'dia': 0.14285714285714285, 'tapi': 0.14285714285714285, 'memang': 0.0, 'milih': 0.0}
# Data4 : {'aku': 0.25, 'cinta': 0.125, 'kamu': 0.125, 'dan': 0.0, 'dia': 0.125, 'tapi': 0.125, 'memang': 0.125, 'milih': 0.125}

# %%
import math
data_idf = {}
for kata in kamus_kata:
  hitung = math.log(len(d_list)/kamus_kata[kata], 10)
  data_idf[kata] = hitung

print(data_idf)
# Out:
# {'aku': 0.0, 'cinta': 0.0, 'kamu': 0.0, 'dan': 0.6020599913279623, 'dia': 0.1249387366082999, 'tapi': 0.30102999566398114, 'memang': 0.6020599913279623, 'milih': 0.6020599913279623}

# %%
#TF-IDF
hasil = []
data_sementara = {}

for index in range (len(data_list)):
  for i in data_list[index]:
    hitung = data_list [index][i] * data_idf[i]
    data_sementara[i] = round(hitung, 3)
  hasil.append(data_sementara)
  data_sementara = {}

for i in range(len(hasil)):
  print(f"Data{i} : {hasil[i]}")
# Out:
# Data0 : {'aku': 0.0, 'cinta': 0.0, 'kamu': 0.0, 'dan': 0.0, 'dia': 0.0, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}
# Data1 : {'aku': 0.0, 'cinta': 0.0, 'kamu': 0.0, 'dan': 0.12, 'dia': 0.025, 'tapi': 0.0, 'memang': 0.0, 'milih': 0.0}
# Data2 : {'aku': 0.0, 'cinta': 0.0, 'kamu': 0.0, 'dan': 0.0, 'dia': 0.018, 'tapi': 0.043, 'memang': 0.0, 'milih': 0.0}
# Data3 : {'aku': 0.0, 'cinta': 0.0, 'kamu': 0.0, 'dan': 0.0, 'dia': 0.016, 'tapi': 0.038, 'memang': 0.075, 'milih': 0.075}
